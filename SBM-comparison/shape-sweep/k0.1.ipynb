# %% [markdown]
# # ANALYSIS

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import re
from pathlib import Path

# %% [markdown]
# ## Extract Akantu simulations

# %%
BASE_DIR = Path('/scratch/saporito/Frag3D')
FINAL_STEP = 'step_36533'
MASS_THRESHOLD = 3e-8
DENSITY = 2203.0  # kg/m^3

SIM_FOLDERS = [
    'sim_vel1.0e+03_sf4.0e-01_T4.0e-05_k1.0e-01_sh_circular_thxy0.0e+00_thz0.0e+00_sgn1.0e+00_cntr_0.0e+00_0.0e+00',
    'sim_vel1.0e+03_sf4.0e-01_T4.0e-05_k1.0e-01_sh_parabolic_thxy0.0e+00_thz0.0e+00_sgn1.0e+00_cntr_0.0e+00_0.0e+00'
]

def make_label(folder: str) -> str:
    m_vel  = re.search(r'vel([^_]+)', folder)
    m_k    = re.search(r'_k([^_]+)', folder)
    m_sh   = re.search(r'sh_([a-zA-Z]+)', folder)
    
    m_thxy = re.search(r'thxy([^_]+)', folder)
    m_thz  = re.search(r'thz([^_]+)',  folder)
    m_cntr = re.search(r'cntr_([0-9.e+\-]+)_([0-9.e+\-]+)', folder)
    
    vel  = float(m_vel.group(1)) if m_vel else 0.0
    k    = float(m_k.group(1)) if m_k else 0.0
    sh   = m_sh.group(1) if m_sh else 'unknown'
    
    thxy   = float(m_thxy.group(1)) if m_thxy else 0
    thz    = float(m_thz.group(1))  if m_thz  else 0
    cx, cy = (float(m_cntr.group(1)), float(m_cntr.group(2))) if m_cntr else (0, 0)
    
    return f'vel={vel:.1e} k={k:.2f} sh={sh} | thxy={thxy:.0f}° thz={thz:.0f}° | cntr=({cx:.2g},{cy:.2g})'

LABELS = [make_label(f) for f in SIM_FOLDERS]
COLORS = plt.cm.tab10(np.linspace(0, 0.5, len(SIM_FOLDERS)))

print('Simulation labels:')
for i, lbl in enumerate(LABELS):
    print(f'  [{i}] {lbl}')
# Out:
# Simulation labels:
#   [0] vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0° | cntr=(0,0)
#   [1] vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0° | cntr=(0,0)

# %% [markdown]
# ## Extract SBM simulations

# %%
SBM_DIR = Path('/home/saporito/NASA-breakup-model-cpp/AkantuComparison/')

SBM_FOLDERS = [
    'circular-k0.1',
    'parabolic-k0.1'
]


def parse_velocity_vector(v_str):
    """
    Convert string:
    '[4.523031151046023 -226.04863147567926 -145.7030932365865]'
    -> np.array([x,y,z])
    """
    if pd.isna(v_str): return np.zeros(3)
    vals = np.fromstring(v_str.strip('[]'), sep=' ')

    if len(vals) != 3:
        raise ValueError(f'Cannot parse velocity vector: {v_str}')

    return vals


def load_sbm_data(file: Path) -> dict:

    if not file.exists():
        print(f'WARNING: Missing SBM file {file}')
        return None

    df = pd.read_csv(file)

    # keep only target fragments
    df = df[
        df['Name'] == 'Target-Collision-Fragment'
    ].copy()

    # mass threshold
    df = df[
        df['Mass [kg]'] > MASS_THRESHOLD
    ].copy()

    n_fragments = len(df)

    if n_fragments == 0:
        return {
            'mass': np.array([]),
            'volume': np.array([]),
            'vmag': np.array([]),
            'vx': np.array([]),
            'vy': np.array([]),
            'vz': np.array([]),
            'ke': np.array([]),
            'n_fragments': 0
        }

    vel_vectors = np.vstack(df['Velocity [m/s]'].apply(parse_velocity_vector).to_numpy())

    vx = vel_vectors[:, 0]
    vy = vel_vectors[:, 1]
    vz = vel_vectors[:, 2]

    vmag = np.linalg.norm(vel_vectors,axis=1)

    mass = (df['Mass [kg]'].to_numpy())

    kinetic_energy = (0.5 * mass * vmag**2)

    characteristic_length = (df['Characteristic Length [m]'].to_numpy())

    area = (df['Area [m^2]'].to_numpy())

    volume = (area * characteristic_length)

    return {

        'mass': mass,
        'volume': volume,

        'vmag': vmag,
        'vx': vx,
        'vy': vy,
        'vz': vz,

        'ke': kinetic_energy,

        'length': characteristic_length,
        'area_mass': (
            df['A/M [m^2/kg]']
            .to_numpy()
        ),
        'area': area,

        'n_fragments': n_fragments
    }


# Load both MC and noMC versions
sbm_fragment_data = {}

for folder in SBM_FOLDERS:

    mc_file = (
        SBM_DIR / folder /
        'input-output-MC' /
        'result.csv'
    )

    nomc_file = (
        SBM_DIR / folder /
        'input-output-noMC' /
        'result.csv'
    )

    mc_key = f'{folder} [MC]'
    nomc_key = f'{folder} [noMC]'

    sbm_fragment_data[mc_key] = load_sbm_data(mc_file)
    sbm_fragment_data[nomc_key] = load_sbm_data(nomc_file)

print(
    f'Loaded {len(sbm_fragment_data)} SBM datasets'
)
# Out:
# Loaded 4 SBM datasets

# %% [markdown]
# ## Load final-step data for all Akantu simulations

# %%
SCALAR_ATTRS = ['econ', 'edis', 'ekin', 'epot', 'erev', 'nb_fragments', 'total_energy', 'work']

scalar_rows = []
fragment_data = {}

for folder, label in zip(SIM_FOLDERS, LABELS):
    h5path = BASE_DIR / folder / 'data.h5'
    with h5py.File(h5path, 'r') as f:
        step = f[FINAL_STEP]

        row = {'sim': label}
        for attr in SCALAR_ATTRS:
            row[attr] = float(step.attrs[attr])
        masses = step['fragment_mass'][:]
        vels   = step['fragment_velocity'][:]

        row['nb_fragments_heavy'] = int((masses >= MASS_THRESHOLD).sum())
        scalar_rows.append(row)

        vmag = np.linalg.norm(vels, axis=1)
        fragment_data[label] = {

        'mass': masses,

        'volume': (
            masses / DENSITY
        ),

        'vmag': vmag,
        'vx': vels[:, 0],
        'vy': vels[:, 1],
        'vz': vels[:, 2],
    }

print('Done loading', len(scalar_rows), 'simulations.')
# Out:
# Done loading 2 simulations.

# %% [markdown]
# ## Select simulations to keep

# %%
AKANTU_SELECTION = [
    LABELS[0],
    LABELS[1]
]

SBM_SELECTION_MC = [
    'circular-k0.1 [MC]'
]

SBM_SELECTION_NOMC = [
    'circular-k0.1 [noMC]'
]

COMPARISON_COLORS = {
    'akantu': plt.cm.Blues,
    'sbm': plt.cm.Reds,
}

# %% [markdown]
# ## Fragment statistics table
# mean / max / min / std of mass, |v|, vx, vy, vz, volume, number of fragments, kinetic energy

# %%
def filter_fragment_data(fragment_data, mass_threshold):
    filtered_data = {}

    for label, fd in fragment_data.items():

        mask = fd['mass'] > mass_threshold

        filtered_data[label] = {
            key: values[mask]
            for key, values in fd.items()
        }

    return filtered_data

fragment_data = filter_fragment_data(
    fragment_data,
    MASS_THRESHOLD
)

# %%
STAT_FUNCS = {
    'mean': np.mean,
    'min': np.min,
    'max': np.max,
    'std': np.std
}

FRAG_KEYS = [
    'mass',
    'volume',
    'vmag',
    'vx',
    'vy',
    'vz'
]

FRAG_LABELS = [
    'Mass',
    'Volume',
    '|v|',
    'vx',
    'vy',
    'vz'
]
df_scalar = pd.DataFrame(scalar_rows).set_index('sim')


rows = []
for sim_label in AKANTU_SELECTION:

    if sim_label not in fragment_data:
        continue

    row = {'dataset': sim_label,'type': 'Akantu'}

    scalar_row = df_scalar.loc[sim_label]

    row['E_con'] = scalar_row['econ']
    row['E_dis'] = scalar_row['edis']
    row['E_kin'] = scalar_row['ekin']
    row['E_pot'] = scalar_row['epot']
    row['E_rev'] = scalar_row['erev']
    row['E_tot'] = scalar_row['total_energy']
    row['Work'] = scalar_row['work']

    row['N_fragments'] = int(scalar_row['nb_fragments_heavy'])

    fd = fragment_data[sim_label]

    for key, label in zip(FRAG_KEYS,FRAG_LABELS):

        arr = fd[key]

        if len(arr) == 0:
            row[f'{label}_mean'] = np.nan
            row[f'{label}_min'] = np.nan
            row[f'{label}_max'] = np.nan
            row[f'{label}_std'] = np.nan

        else:
            row[f'{label}_mean'] = np.mean(arr)
            row[f'{label}_min'] = np.min(arr)
            row[f'{label}_max'] = np.max(arr)
            row[f'{label}_std'] = np.std(arr)

    rows.append(row)

for dataset in (SBM_SELECTION_MC + SBM_SELECTION_NOMC):

    if dataset not in sbm_fragment_data:
        print(f'Skipping {dataset}')
        continue

    fd = sbm_fragment_data[dataset]

    if fd is None:
        continue

    row = {
        'dataset': dataset,
        'type': 'SBM'
    }

    row['E_con'] = np.nan
    row['E_dis'] = np.nan
    row['E_kin'] = fd['ke'].sum() if 'ke' in fd else np.nan
    row['E_pot'] = np.nan
    row['E_rev'] = np.nan
    row['E_tot'] = np.nan
    row['Work'] = np.nan

    row['N_fragments'] = (
        fd['n_fragments']
    )

    for key, label in zip(
        FRAG_KEYS,
        FRAG_LABELS
    ):

        arr = fd[key]

        if len(arr) == 0:

            row[f'{label}_mean'] = np.nan
            row[f'{label}_min'] = np.nan
            row[f'{label}_max'] = np.nan
            row[f'{label}_std'] = np.nan

        else:

            row[f'{label}_mean'] = np.mean(arr)
            row[f'{label}_min'] = np.min(arr)
            row[f'{label}_max'] = np.max(arr)
            row[f'{label}_std'] = np.std(arr)

    rows.append(row)
df_results = pd.DataFrame(rows)

df_results = df_results.set_index(
    ['type', 'dataset']
)

pd.set_option(
    'display.float_format',
    '{:.4e}'.format
)

pd.set_option(
    'display.max_columns',
    None
)

display(df_results)
# Out:
#                                                                E_con  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 0.0000e+00
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 0.0000e+00
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                                E_dis  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 9.7541e-04
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 3.5977e-03
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                                E_kin  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 2.1305e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 7.1882e+00
# SBM    circular-k0.1 [MC]                                 2.0944e+01
#        circular-k0.1 [noMC]                               7.7863e+00
#
#                                                                E_pot  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 3.0404e-01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 2.1191e-02
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                                E_rev  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 4.3737e-07
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 1.0156e-06
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                                E_tot  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 2.1610e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 7.2130e+00
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                                 Work  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 0.0000e+00
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 0.0000e+00
# SBM    circular-k0.1 [MC]                                        NaN
#        circular-k0.1 [noMC]                                      NaN
#
#                                                            N_fragments  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...           24
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0...           87
# SBM    circular-k0.1 [MC]                                           35
#        circular-k0.1 [noMC]                                         34
#
#                                                            Mass_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 6.8702e-04
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 1.8831e-04
# SBM    circular-k0.1 [MC]                                 1.5736e-04
#        circular-k0.1 [noMC]                               1.0513e-06
#
#                                                             Mass_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 3.0444e-08
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 3.0155e-08
# SBM    circular-k0.1 [MC]                                 1.3253e-07
#        circular-k0.1 [noMC]                               7.5019e-08
#
#                                                             Mass_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 5.4588e-03
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 5.4601e-03
# SBM    circular-k0.1 [MC]                                 5.4787e-03
#        circular-k0.1 [noMC]                               1.0195e-05
#
#                                                             Mass_std  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 1.8036e-03
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 9.9628e-04
# SBM    circular-k0.1 [MC]                                 9.1260e-04
#        circular-k0.1 [noMC]                               1.8864e-06
#
#                                                            Volume_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...   3.1186e-07
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0...   8.5480e-08
# SBM    circular-k0.1 [MC]                                   9.0500e-08
#        circular-k0.1 [noMC]                                 3.7890e-10
#
#                                                            Volume_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  1.3819e-11
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0...  1.3688e-11
# SBM    circular-k0.1 [MC]                                  3.7192e-11
#        circular-k0.1 [noMC]                                3.6275e-11
#
#                                                            Volume_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  2.4779e-06
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0...  2.4785e-06
# SBM    circular-k0.1 [MC]                                  3.1347e-06
#        circular-k0.1 [noMC]                                3.5086e-09
#
#                                                            Volume_std  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  8.1870e-07
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0...  4.5224e-07
# SBM    circular-k0.1 [MC]                                  5.2209e-07
#        circular-k0.1 [noMC]                                6.7048e-10
#
#                                                             |v|_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 5.0828e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 5.2183e+02
# SBM    circular-k0.1 [MC]                                 1.2639e+02
#        circular-k0.1 [noMC]                               5.3493e+02
#
#                                                              |v|_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 5.2755e-04
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 8.2565e-03
# SBM    circular-k0.1 [MC]                                 6.2299e+00
#        circular-k0.1 [noMC]                               2.4139e+01
#
#                                                              |v|_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 1.0001e+03
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 9.8322e+02
# SBM    circular-k0.1 [MC]                                 1.5009e+03
#        circular-k0.1 [noMC]                               2.6913e+03
#
#                                                              |v|_std  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 3.3098e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 3.1450e+02
# SBM    circular-k0.1 [MC]                                 2.4408e+02
#        circular-k0.1 [noMC]                               5.4560e+02
#
#                                                               vx_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  5.8403e+00
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... -5.8340e-02
# SBM    circular-k0.1 [MC]                                 -1.0254e+01
#        circular-k0.1 [noMC]                               -1.1795e+01
#
#                                                                vx_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... -7.6495e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... -2.1211e+01
# SBM    circular-k0.1 [MC]                                 -3.1481e+02
#        circular-k0.1 [noMC]                               -1.0221e+03
#
#                                                               vx_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 1.6636e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 1.6781e+01
# SBM    circular-k0.1 [MC]                                 1.4487e+02
#        circular-k0.1 [noMC]                               1.9823e+03
#
#                                                               vx_std  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 5.6706e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 7.3346e+00
# SBM    circular-k0.1 [MC]                                 7.3936e+01
#        circular-k0.1 [noMC]                               4.9016e+02
#
#                                                               vy_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  5.8575e+00
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... -1.0468e+00
# SBM    circular-k0.1 [MC]                                  1.7151e+01
#        circular-k0.1 [noMC]                               -2.3123e+01
#
#                                                                vy_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... -8.7968e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... -3.4477e+01
# SBM    circular-k0.1 [MC]                                 -2.3601e+02
#        circular-k0.1 [noMC]                               -1.3928e+03
#
#                                                               vy_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 1.0945e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 1.4422e+01
# SBM    circular-k0.1 [MC]                                 6.7335e+02
#        circular-k0.1 [noMC]                               1.8199e+03
#
#                                                               vy_std  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 4.8408e+01
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 7.4137e+00
# SBM    circular-k0.1 [MC]                                 1.3802e+02
#        circular-k0.1 [noMC]                               4.5662e+02
#
#                                                              vz_mean  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 5.0080e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 5.2141e+02
# SBM    circular-k0.1 [MC]                                 3.2265e+01
#        circular-k0.1 [noMC]                               3.2365e+00
#
#                                                                vz_min  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°...  4.6867e-04
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... -2.7134e+00
# SBM    circular-k0.1 [MC]                                 -1.2052e+02
#        circular-k0.1 [noMC]                               -1.0575e+03
#
#                                                               vz_max  \
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 1.0001e+03
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 9.8322e+02
# SBM    circular-k0.1 [MC]                                 1.3039e+03
#        circular-k0.1 [noMC]                               1.0221e+03
#
#                                                               vz_std
# type   dataset
# Akantu vel=1.0e+03 k=0.10 sh=circular | thxy=0° thz=0°... 3.3387e+02
#        vel=1.0e+03 k=0.10 sh=parabolic | thxy=0° thz=0... 3.1503e+02
# SBM    circular-k0.1 [MC]                                 2.2270e+02
#        circular-k0.1 [noMC]                               3.6660e+02

# %% [markdown]
# ## Distribution plots functions

# %%
from scipy.stats import gaussian_kde

def kde_line(
    ax,
    arr,
    color,
    label,
    log_x=False,
    bw_method='scott',
    min_kde_samples=5
):
    """
    Robust distribution plotting.

    Cases:
    - n < 2: skip
    - identical values: vertical spike
    - very small n (< min_kde_samples): rug plot
    - otherwise: KDE

    Parameters
    ----------
    ax : matplotlib axis
    arr : np.ndarray
        Data array
    color : str
    label : str
    log_x : bool
        Use log10 transform for KDE and x-axis
    bw_method : str or float
        KDE bandwidth
    min_kde_samples : int
        Minimum samples required before using KDE
    """

    # Remove invalid values
    data = np.asarray(arr)

    if log_x:
        data = data[data > 0]
    else:
        data = data[np.isfinite(data)]

    n = len(data)

    if n < 2:
        print(f'Skipping {label}: fewer than 2 samples')
        return

    # Transform to log-space if needed
    kde_data = np.log10(data) if log_x else data

    # --------------------------------------------------
    # CASE 1: Degenerate distribution (all identical)
    # --------------------------------------------------
    if np.ptp(kde_data) == 0:

        x0 = data[0]

        ax.axvline(
            x=x0,
            color=color,
            linewidth=2.5,
            linestyle='--',
            alpha=0.9,
            label=f'{label} (identical masses)'
        )

        # show fragment count
        ax.scatter(
            np.full(n, x0),
            np.zeros(n),
            color=color,
            s=40,
            alpha=0.8,
            zorder=5
        )

        print(
            f'{label}: degenerate distribution '
            f'(n={n}, x={x0:.3e})'
        )

        return

    # --------------------------------------------------
    # CASE 2: Too few samples for meaningful KDE
    # --------------------------------------------------
    if n < min_kde_samples:

        ax.scatter(
            data,
            np.zeros(n),
            color=color,
            s=50,
            alpha=0.8,
            marker='|',
            label=f'{label} (n={n})',
            zorder=5
        )

        print(
            f'{label}: too few samples for KDE '
            f'(n={n})'
        )

        return

    # --------------------------------------------------
    # CASE 3: Standard KDE
    # --------------------------------------------------
    try:

        kde = gaussian_kde(
            kde_data,
            bw_method=bw_method
        )

        xs_kde = np.linspace(
            kde_data.min(),
            kde_data.max(),
            500
        )

        ys = kde(xs_kde)

        # Convert back from log-space
        if log_x:
            xs = 10 ** xs_kde

            # Jacobian correction
            ys = ys / (xs * np.log(10))
        else:
            xs = xs_kde

        ax.plot(
            xs,
            ys,
            color=color,
            linewidth=1.8,
            label=label
        )

        ax.fill_between(
            xs,
            ys,
            alpha=0.12,
            color=color
        )

    except Exception as e:

        print(
            f'KDE failed for {label}: {e}'
        )


def plot_kde_combined(frag_data, labels, colors, key, xlabel, log_x=False):
    fig, ax = plt.subplots(figsize=(9, 4))
    for label, color in zip(labels, colors):
        if label in frag_data:
            kde_line(ax, frag_data[label][key], color, label, log_x)
            
    if log_x:
        ax.set_xscale('log')
    ax.set_xlabel(xlabel, fontsize=11)
    ax.set_ylabel('Probability density', fontsize=11)
    ax.set_title(f'Distribution of {xlabel} - all configs', fontsize=12)
    
    handles, legend_labels = ax.get_legend_handles_labels()
    if handles:
        ax.legend(fontsize=7, framealpha=0.5)
        
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2e'))
    plt.tight_layout()
    plt.show()


def plot_kde_individual(frag_data, labels, colors, key, xlabel, log_x=False):
    valid_mins = []
    valid_maxs = []
    
    for lbl in labels:
        if lbl in frag_data:
            arr = frag_data[lbl][key]
            data = arr[arr > 0] if log_x else arr
            if len(data) >= 2 and np.ptp(data) > 0:
                valid_mins.append(data.min())
                valid_maxs.append(data.max())
                
    if not valid_mins:
        print(f"Skipping individual plots for {xlabel}: Not enough valid data points.")
        return
        
    xmin, xmax = min(valid_mins), max(valid_maxs)
    
    for label, color in zip(labels, colors):
        if label not in frag_data:
            continue
            
        arr = frag_data[label][key]
        data = arr[arr > 0] if log_x else arr
        if len(data) < 2:
            continue
            
        fig, ax = plt.subplots(figsize=(5, 4))
        kde_line(ax, frag_data[label][key], color, label=None, log_x=log_x)
        
        if log_x:
            ax.set_xscale('log')
        ax.set_xlim(xmin, xmax)
        ax.set_title(label, fontsize=8, wrap=True)
        ax.set_xlabel(xlabel, fontsize=9)
        ax.set_ylabel('Probability density', fontsize=10)
        ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2e'))
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## Scatter plot functions

# %%
def scatter_vmag_vs_mass(frag_data, labels, colors, title_suffix='', ax=None):
    standalone = ax is None
    if standalone:
        fig, ax = plt.subplots(figsize=(7, 4.5))
        
    for label, color in zip(labels, colors):
        if label in frag_data:
            fd = frag_data[label]
            if len(fd['mass']) == 0: 
                continue
            ax.scatter(fd['mass'], fd['vmag'], s=20, alpha=0.5,
                       color=color, label=label, linewidths=0)
                       
    ax.set_xscale('log')
    ax.set_xlabel('Fragment mass', fontsize=10)
    ax.set_ylabel('Velocity magnitude |v|', fontsize=10)
    ax.set_title(f'|v| vs mass{title_suffix}', fontsize=11)
    
    if standalone:
        handles, legend_labels = ax.get_legend_handles_labels()
        if handles:
            ax.legend(fontsize=7, framealpha=0.5)
        plt.tight_layout()
        plt.show()

# %%
def plot_kde_akantu_vs_sbm(
    akantu_data,
    sbm_data,
    akantu_selection,
    sbm_selection,
    key,
    xlabel,
    log_x=False,
    figsize=(9, 4)
):

    fig, ax = plt.subplots(figsize=figsize)

    ak_colors = COMPARISON_COLORS['akantu'](np.linspace( 0.4, 0.9, max(len(akantu_selection), 1)))

    for label, color in zip(akantu_selection, ak_colors):

        if label not in akantu_data:
            continue

        kde_line(ax=ax, arr=akantu_data[label][key],color=color,label=f'Akantu | {label}',log_x=log_x)

    sbm_colors = COMPARISON_COLORS['sbm']( np.linspace( 0.4, 0.9, max(len(sbm_selection), 1)))

    for label, color in zip( sbm_selection, sbm_colors ):

        if label not in sbm_data:
            continue

        if sbm_data[label] is None:
            continue

        kde_line(ax=ax,  arr=sbm_data[label][key], color=color, label=f'SBM | {label}', log_x=log_x)

    if log_x:
        ax.set_xscale('log')

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Probability density')

    ax.set_title(f'Akantu vs SBM — {xlabel}')

    ax.yaxis.set_major_formatter( ticker.FormatStrFormatter('%.2e'))

    ax.legend( fontsize=8,framealpha=0.6)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Plots

# %%
PLOTS = [

    (
        'mass',
        'Fragment mass [kg]',
        True
    ),

    (
        'volume',
        'Fragment volume [m³]',
        True
    ),

    (
        'vmag',
        'Velocity magnitude |v| [m/s]',
        False
    ),

    (
        'vx',
        'Velocity vx [m/s]',
        False
    ),

    (
        'vy',
        'Velocity vy [m/s]',
        False
    ),

    (
        'vz',
        'Velocity vz [m/s]',
        False
    ),
]

for key, xlabel, log_x in PLOTS:

    plot_kde_akantu_vs_sbm(
        akantu_data=fragment_data,
        sbm_data=sbm_fragment_data,
        akantu_selection=AKANTU_SELECTION,
        sbm_selection=SBM_SELECTION_MC,
        key=key,
        xlabel=xlabel,
        log_x=log_x
    )

    plot_kde_akantu_vs_sbm(
        akantu_data=fragment_data,
        sbm_data=sbm_fragment_data,
        akantu_selection=AKANTU_SELECTION,
        sbm_selection=SBM_SELECTION_NOMC,
        key=key,
        xlabel=xlabel,
        log_x=log_x
    )

# %%
def scatter_vmag_vs_mass_comparison(
    akantu_data,
    sbm_data,
    akantu_selection,
    sbm_selection,
    figsize=(8, 5),
    alpha=0.5,
    marker_size=18
):

    fig, ax = plt.subplots(figsize=figsize)

    ak_colors = COMPARISON_COLORS['akantu'](
        np.linspace(
            0.4,
            0.9,
            max(len(akantu_selection), 1)
        )
    )

    for label, color in zip(
        akantu_selection,
        ak_colors
    ):

        if label not in akantu_data:
            continue

        fd = akantu_data[label]

        if len(fd['mass']) == 0:
            continue

        ax.scatter(
            fd['mass'],
            fd['vmag'],
            s=marker_size,
            alpha=alpha,
            color=color,
            linewidths=0,
            label=f'Akantu | {label}'
        )
    sbm_colors = COMPARISON_COLORS['sbm'](
        np.linspace(
            0.4,
            0.9,
            max(len(sbm_selection), 1)
        )
    )

    for label, color in zip(
        sbm_selection,
        sbm_colors
    ):

        if label not in sbm_data:
            continue

        if sbm_data[label] is None:
            continue

        fd = sbm_data[label]

        if len(fd['mass']) == 0:
            continue

        ax.scatter(
            fd['mass'],
            fd['vmag'],
            s=marker_size,
            alpha=alpha,
            color=color,
            linewidths=0,
            label=f'SBM | {label}'
        )

    ax.set_xscale('log')

    ax.set_xlabel('Fragment mass [kg]')
    ax.set_ylabel('Velocity magnitude |v| [m/s]')

    ax.set_title(
        'Akantu vs SBM — |v| vs mass'
    )

    ax.legend(
        fontsize=8,
        framealpha=0.6
    )

    plt.tight_layout()
    plt.show()

# %%
scatter_vmag_vs_mass_comparison(
    akantu_data=fragment_data,
    sbm_data=sbm_fragment_data,
    akantu_selection=AKANTU_SELECTION,
    sbm_selection=SBM_SELECTION_MC,
    figsize=(9, 5),
    alpha=0.5,
    marker_size=30
)

scatter_vmag_vs_mass_comparison(
    akantu_data=fragment_data,
    sbm_data=sbm_fragment_data,
    akantu_selection=AKANTU_SELECTION,
    sbm_selection=SBM_SELECTION_NOMC,
    figsize=(9, 5),
    alpha=0.5,
    marker_size=30
)

# %%
def scatter_vmag_vs_volume_comparison(
    akantu_data,
    sbm_data,
    akantu_selection,
    sbm_selection,
    figsize=(8, 5),
    alpha=0.9,
    marker_size=30
):

    fig, ax = plt.subplots(figsize=figsize)

    ak_colors = COMPARISON_COLORS['akantu'](
        np.linspace(
            0.4,
            0.9,
            max(len(akantu_selection), 1)
        )
    )

    for label, color in zip(
        akantu_selection,
        ak_colors
    ):

        fd = akantu_data[label]

        ax.scatter(
            fd['volume'],
            fd['vmag'],
            s=marker_size,
            alpha=alpha,
            color=color,
            linewidths=0,
            label=f'Akantu | {label}'
        )

    sbm_colors = COMPARISON_COLORS['sbm'](
        np.linspace(
            0.4,
            0.9,
            max(len(sbm_selection), 1)
        )
    )

    for label, color in zip(
        sbm_selection,
        sbm_colors
    ):

        fd = sbm_data[label]

        ax.scatter(
            fd['volume'],
            fd['vmag'],
            s=marker_size,
            alpha=alpha,
            color=color,
            linewidths=0,
            label=f'SBM | {label}'
        )

    ax.set_xscale('log')

    ax.set_xlabel(
        'Fragment volume [m³]'
    )

    ax.set_ylabel(
        'Velocity magnitude |v| [m/s]'
    )

    ax.set_title(
        'Akantu vs SBM — |v| vs volume'
    )

    ax.legend(
        fontsize=8,
        framealpha=0.6
    )

    plt.tight_layout()
    plt.show()

# %%
scatter_vmag_vs_volume_comparison(
    akantu_data=fragment_data,
    sbm_data=sbm_fragment_data,
    akantu_selection=AKANTU_SELECTION,
    sbm_selection=SBM_SELECTION_MC,
)

scatter_vmag_vs_volume_comparison(
    akantu_data=fragment_data,
    sbm_data=sbm_fragment_data,
    akantu_selection=AKANTU_SELECTION,
    sbm_selection=SBM_SELECTION_NOMC,
)
