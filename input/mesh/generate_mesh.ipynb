# %%
import sys
import os

spack_python_paths = [
    "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/python-venv-1.0-odeiohff2sjs7n2366iy65hza6u5m2jk/lib/python3.11/site-packages",
    "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-numpy-1.26.4-k5bsbdhszjly3xvxnjqxhlaoyik3yllz/lib/python3.11/site-packages",
    "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-pybind11-2.12.0-x2gzd4nho3hb73aicdm7pqxtuqyxctxn/lib/python3.11/site-packages",
    "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-scipy-1.13.0-4grab6xfa57tpoyrrvjinjz3dtp4qm2v/lib/python3.11/site-packages",
    "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/gmsh-4.13.1-ohqocjc6t25l5nx25uktkdsp23zxpc7r/lib"
]

for path in spack_python_paths:
    if path not in sys.path:
        sys.path.insert(0, path)

os.environ['LD_LIBRARY_PATH'] = "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-x86_64_v3/gcc-11.4.1/pkgconf-2.2.0-c2erxugcxqvb3pthpbwwg22hfp7nuo7f/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/python-venv-1.0-odeiohff2sjs7n2366iy65hza6u5m2jk/lib64:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/python-venv-1.0-odeiohff2sjs7n2366iy65hza6u5m2jk/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-numpy-1.26.4-k5bsbdhszjly3xvxnjqxhlaoyik3yllz/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-pybind11-2.12.0-x2gzd4nho3hb73aicdm7pqxtuqyxctxn/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/py-scipy-1.13.0-4grab6xfa57tpoyrrvjinjz3dtp4qm2v/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/gmsh-4.13.1-ohqocjc6t25l5nx25uktkdsp23zxpc7r/lib64:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/scotch-7.0.4-orrlkmig2tvnokqqy7lxqcgqwagw6qvn/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/mumps-5.6.2-wzowpatszal6o5ljyd3xzbckjovul4fj/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/libfabric-1.21.0-q7icjqlejr2qemrywkuiirxnxzor5ly5/lib64:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/libfabric-1.21.0-q7icjqlejr2qemrywkuiirxnxzor5ly5/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/openmpi-5.0.3-i7bson2onqxzu5lpmymxfucij6wb5tbf/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/openblas-0.3.27-xozwgqxy3vsx3qwtigdajqpzx2dpetyl/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/boost-1.85.0-hgidf2kwcmalglmxfi2ttgfxt4pn2235/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/python-3.11.7-mo6cs2ftazilg45a3fna3d3teo6znedd/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-x86_64_v3/gcc-11.4.1/zlib-ng-2.1.6-7wmxgaymwqu4zk5w2ds5d5kdny4umo3q/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-x86_64_v3/gcc-11.4.1/gcc-13.2.0-hv54pwqhzsv2gfljpsyffs4xo2u7swfj/lib64:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-x86_64_v3/gcc-11.4.1/gcc-13.2.0-hv54pwqhzsv2gfljpsyffs4xo2u7swfj/lib:/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/hdf5-1.14.3-ig2asq5lgnvvypan7bjdyg7pfpn6p6tr/lib"

# %%
gmsh_bin = "/ssoft/spack/pinot-noir/jed/v2/spack/opt/spack/linux-rhel9-icelake/gcc-13.2.0/gmsh-4.13.1-ohqocjc6t25l5nx25uktkdsp23zxpc7r/bin"

os.environ['PATH'] = gmsh_bin + os.path.pathsep + os.environ.get('PATH', '')

# %%
import subprocess
import time

# %%
# Plate dimensions
L, W = 0.05, 0.05
lpz = 0.007555556       # Process zone length (based on ceramic material properties)
lc = L / 160       # Mesh characteristic length
h = 0.001

p = 2               # Polynomial order

# %%
# Genrate the .geo file

output_name = f"plate_{L:.2e}x{W:.2e}x{h:.2e}_P{p}"
 
geo_file = f"""
// Define the points
Point(1) = {{{-L/2}, {-W/2}, {-h/2}, {lc}}};
Point(2) = {{{L/2}, {-W/2}, {-h/2}, {lc}}};
Point(3) = {{{L/2}, {W/2}, {-h/2}, {lc}}};
Point(4) = {{{-L/2}, {W/2}, {-h/2}, {lc}}};
Point(5) = {{{-L/2}, {-W/2}, {h/2}, {lc}}};
Point(6) = {{{L/2}, {-W/2}, {h/2}, {lc}}};
Point(7) = {{{L/2}, {W/2}, {h/2}, {lc}}};
Point(8) = {{{-L/2}, {W/2}, {h/2}, {lc}}};

// Define the bottom face lines
Line(1) = {{1, 2}};
Line(2) = {{2, 3}};
Line(3) = {{3, 4}};
Line(4) = {{4, 1}};

// Define the top face lines
Line(5) = {{5, 6}};
Line(6) = {{6, 7}};
Line(7) = {{7, 8}};
Line(8) = {{8, 5}};

// Define vertical lines connecting top and bottom faces
Line(9) = {{1, 5}};
Line(10) = {{2, 6}};
Line(11) = {{3, 7}};
Line(12) = {{4, 8}};

// Define the line loops for surfaces
Line Loop(1) = {{1, 2, 3, 4}};  // Bottom face
Line Loop(2) = {{5, 6, 7, 8}};  // Top face
Line Loop(3) = {{1, 10, -5, -9}}; // Side 1
Line Loop(4) = {{2, 11, -6, -10}}; // Side 2
Line Loop(5) = {{3, 12, -7, -11}}; // Side 3
Line Loop(6) = {{4, 9, -8, -12}}; // Side 4

// Define surfaces
Plane Surface(1) = {{1}}; // Bottom face
Plane Surface(2) = {{2}}; // Top face
Plane Surface(3) = {{3}}; // Side 1
Plane Surface(4) = {{4}}; // Side 2
Plane Surface(5) = {{5}}; // Side 3
Plane Surface(6) = {{6}}; // Side 4

// Define the volume
Surface Loop(1) = {{1, 2, 3, 4, 5, 6}};
Volume(1) = {{1}};

// Physical groups
Physical Surface("bottom") = {{1}};
Physical Surface("top") = {{2}};
Physical Surface("sides") = {{3, 4, 5, 6}};
Physical Volume("plate") = {{1}};

// Meshing properties
Mesh.Algorithm = 5;
Mesh.ElementOrder = {p};
"""

with open(output_name + ".geo", "w") as f:
    f.write(geo_file)

# %%
# Generate the mesh
ret = subprocess.Popen("gmsh -3 " + output_name + ".geo -o " + output_name + ".msh", shell=True)
if ret.returncode:
    print("Beware, gmsh could not run: mesh is not regenerated")
else:
    print("Mesh generated")
# Out:
# Mesh generated
# Info    : Running 'gmsh -3 plate_5.00e-02x5.00e-02x1.00e-03_P2.geo -o plate_5.00e-02x5.00e-02x1.00e-03_P2.msh' [Gmsh 4.13.1, 1 node, max. 1 thread]
# Info    : Started on Mon May 18 10:01:30 2026
# Info    : Reading 'plate_5.00e-02x5.00e-02x1.00e-03_P2.geo'...
# Info    : Done reading 'plate_5.00e-02x5.00e-02x1.00e-03_P2.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000861356s, CPU 0.000858s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Delaunay)
# Info    : Done meshing 2D (Wall 1.38469s, CPU 1.26771s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 70402 nodes...
# Info    : Done tetrahedrizing 70410 nodes (Wall 1.69495s, CPU 1.62665s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added
)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 2.5e-06) with worst = 0.000930721 / average = 0.72084:
# Info    : 0.00 < quality < 0.10 :      1481 elements
# Info    : 0.10 < quality < 0.20 :      4436 elements
# Info    : 0.20 < quality < 0.30 :      7269 elements
# Info    : 0.30 < quality < 0.40 :     10866 elements
# Info    : 0.40 < quality < 0.50 :     16522 elements
# Info    : 0.50 < quality < 0.60 :     36496 elements
# Info    : 0.60 < quality < 0.70 :     78386 elements
# Info    : 0.70 < quality < 0.80 :    120865 elements
# Info    : 0.80 < quality < 0.90 :    112458 elements
# Info    : 0.90 < quality < 1.00 :     40139 elements
# Info    : 12768 edge swaps, 382 node relocations (volume = 2.5e-06): worst = 0.0772542 / average = 0.737488 (Wall 0.263298s, CPU 0.26129s)
# Info    : 13015 edge swaps, 412 node relocations (volume = 2.5e-06): worst = 0.1778 / average = 0.737781 (Wall 0.353997s, CPU 0.335087s)
# Info    : 13027 edge swaps, 414 node relocations (volume = 2.5e-06): worst = 0.1778 / average = 0.737792 (Wall 0.423149s, CPU 0.403999s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         3 elements
# Info    : 0.20 < quality < 0.30 :        36 elements
# Info    : 0.30 < quality < 0.40 :     10520 elements
# Info    : 0.40 < quality < 0.50 :     16296 elements
# Info    : 0.50 < quality < 0.60 :     38615 elements
# Info    : 0.60 < quality < 0.70 :     77491 elements
# Info    : 0.70 < quality < 0.80 :    119433 elements
# Info    : 0.80 < quality < 0.90 :    114682 elements
# Info    : 0.90 < quality < 1.00 :     40582 elements
# Info    : Done optimizing mesh (Wall 1.20116s, CPU 1.14569s)
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 1 order 2
# Info    : [ 10%] Meshing curve 2 order 2
# Info    : [ 20%] Meshing curve 3 order 2
# Info    : [ 20%] Meshing curve 4 order 2
# Info    : [ 30%] Meshing curve 5 order 2
# Info    : [ 30%] Meshing curve 6 order 2
# Info    : [ 40%] Meshing curve 7 order 2
# Info    : [ 40%] Meshing curve 8 order 2
# Info    : [ 50%] Meshing curve 9 order 2
# Info    : [ 50%] Meshing curve 10 order 2
# Info    : [ 60%] Meshing curve 11 order 2
# Info    : [ 60%] Meshing curve 12 order 2
# Info    : [ 70%] Meshing surface 1 order 2
# Info    : [ 70%] Meshing surface 2 order 2
# Info    : [ 80%] Meshing surface 3 order 2
# Info    : [ 80%] Meshing surface 4 order 2
# Info    : [ 90%] Meshing surface 5 order 2
# Info    : [ 90%] Meshing surface 6 order 2
# Info    : [100%] Meshing volume 1 order 2
# Info    : Surface mesh: worst distortion = 1 (0 elements in ]0, 0.2]); worst gamma = 0.557853
# Info    : Volume mesh: worst distortion = 1 (0 elements in ]0, 0.2])
# Info    : Done meshing order 2 (Wall 5.48856s, CPU 5.19369s)
# Info    : 692859 nodes 559774 elements
# Info    : Writing 'plate_5.00e-02x5.00e-02x1.00e-03_P2.msh'...
# Info    : Done writing 'plate_5.00e-02x5.00e-02x1.00e-03_P2.msh'
# Info    : Stopped on Mon May 18 10:01:55 2026 (From start: Wall 25.4224s, CPU 23.6436s)

# %%
visualize = True
if visualize:
    time.sleep(1)
    ret = subprocess.Popen("gmsh " + output_name + ".msh", shell=True)
# Out:
# Info    : Running 'gmsh plate_5.00e-02x5.00e-02x1.00e-03_P2.msh' [Gmsh 4.13.1, 1 node, max. 1 thread]
# Info    : Started on Mon May 18 10:01:59 2026
# Info    : Reading 'plate_5.00e-02x5.00e-02x1.00e-03_P2.msh'...
# Info    : 27 entities
# Info    : 692859 nodes
# Info    : 558470 elements
# Info    : Done reading 'plate_5.00e-02x5.00e-02x1.00e-03_P2.msh'
# Info    : Stopped on Mon May 18 10:02:01 2026 (From start: Wall 1.62237s, CPU 1.45618s)
